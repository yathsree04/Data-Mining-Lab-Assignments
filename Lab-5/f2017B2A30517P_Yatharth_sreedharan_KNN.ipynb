# %% [markdown]
# # K-Nearest Neighbour
#
#
# K nearest neighbors is a simple algorithm that stores all available cases and classifies new cases based on a similarity measure (e.g., distance functions). A new record is classified by a majority vote of its neighbors, with the case being assigned to the class most common amongst its K nearest neighbors measured by a distance function. If K = 1, then the case is simply assigned to the class of its nearest neighbor.
#
# Suppose you want to find out the class of the blue star (BS) in the image below. BS can either be RC or GS. The “K” is KNN algorithm is the nearest neighbor we wish to take the vote from. Let’s say K = 3. Hence, we will now make a circle with BS as the center just as big as to enclose only three datapoints on the plane. The three closest points to BS is all RC. Hence, with a good confidence level, we can say that the BS should belong to the class RC. Here, the choice became very obvious as all three votes from the closest neighbor went to RC. The choice of the parameter K is very crucial in this algorithm.
#
# <img src="img1.png">
#
# The distance functions used for Numeric fields are given below:
# <img src="img2.png">

# %% [markdown]
# ### Libraries useful in K-NN are listed below

# %% [raw]
# To load dataset:    import pandas as pd
# Preprocessing:      from sklearn import preprocessing
# K-NN Classifier:    from sklearn.neighbors import KNeighborsClassifier
# Train & Test Split: from sklearn.model_selection import train_test_split
# K-Fold:             from sklearn.model_selection import cross_val_score
#
# For Prediction and Evaluation
#
# from sklearn.metrics import classification_report,confusion_matrix
# from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Get The Data. Load data "bank-data.csv"

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score

# %%
# import dataset
dataset = pd.read_csv("bank-data.csv",index_col=0)
dataset
# Out:
#          age     sex      region    income married  children  car save_act  \
# id
# ID12101   48  FEMALE  INNER_CITY  17546.00      NO         1   NO       NO
# ID12102   40    MALE        TOWN  30085.10     YES         3  YES       NO
# ID12103   51  FEMALE  INNER_CITY  16575.40     YES         0  YES      YES
# ID12104   23  FEMALE        TOWN  20375.40     YES         3   NO       NO
# ID12105   57  FEMALE       RURAL  50576.30     YES         0   NO      YES
# ID12106   57  FEMALE        TOWN  37869.60     YES         2   NO      YES
# ID12107   22    MALE       RURAL   8877.07      NO         0   NO       NO
# ID12108   58    MALE        TOWN  24946.60     YES         0  YES      YES
# ID12109   37  FEMALE    SUBURBAN  25304.30     YES         2  YES       NO
# ID12110   54    MALE        TOWN  24212.10     YES         2  YES      YES
# ID12111   66  FEMALE        TOWN  59803.90     YES         0   NO      YES
# ID12112   52  FEMALE  INNER_CITY  26658.80      NO         0  YES      YES
# ID12113   44  FEMALE        TOWN  15735.80     YES         1   NO      YES
# ID12114   66  FEMALE        TOWN  55204.70     YES         1  YES      YES
# ID12115   36    MALE       RURAL  19474.60     YES         0   NO      YES
# ID12116   38  FEMALE  INNER_CITY  22342.10     YES         0  YES      YES
# ID12117   37  FEMALE        TOWN  17729.80     YES         2   NO       NO
# ID12118   46  FEMALE    SUBURBAN  41016.00     YES         0   NO      YES
# ID12119   62  FEMALE  INNER_CITY  26909.20     YES         0   NO      YES
# ID12120   31    MALE        TOWN  22522.80     YES         0  YES      YES
# ID12121   61    MALE  INNER_CITY  57880.70     YES         2   NO      YES
# ID12122   50    MALE        TOWN  16497.30     YES         2   NO      YES
# ID12123   54    MALE  INNER_CITY  38446.60     YES         0   NO      YES
# ID12124   27  FEMALE        TOWN  15538.80      NO         0  YES      YES
# ID12125   22    MALE  INNER_CITY  12640.30      NO         2  YES      YES
# ID12126   56    MALE  INNER_CITY  41034.00     YES         0  YES      YES
# ID12127   45    MALE  INNER_CITY  20809.70     YES         0   NO      YES
# ID12128   39  FEMALE        TOWN  20114.00     YES         1   NO       NO
# ID12129   39  FEMALE  INNER_CITY  29359.10      NO         3  YES       NO
# ID12130   61    MALE       RURAL  24270.10     YES         1   NO       NO
# ...      ...     ...         ...       ...     ...       ...  ...      ...
# ID12550   38  FEMALE       RURAL  34061.40      NO         0  YES      YES
# ID12551   42    MALE  INNER_CITY  28938.60     YES         3  YES       NO
# ID12552   43    MALE        TOWN  38540.00      NO         0  YES      YES
# ID12553   59  FEMALE  INNER_CITY  27045.10      NO         0   NO       NO
# ID12554   59  FEMALE       RURAL  51284.30      NO         0  YES      YES
# ID12555   24    MALE  INNER_CITY  16352.20      NO         0   NO      YES
# ID12556   27  FEMALE  INNER_CITY  11866.40     YES         0  YES      YES
# ID12557   32  FEMALE        TOWN  13267.60     YES         0  YES      YES
# ID12558   65  FEMALE  INNER_CITY  61554.60     YES         0   NO      YES
# ID12559   18    MALE    SUBURBAN  13700.20      NO         1   NO      YES
# ID12560   66    MALE        TOWN  46963.90     YES         1   NO      YES
# ID12561   41    MALE  INNER_CITY  23475.60     YES         0  YES       NO
# ID12562   64  FEMALE    SUBURBAN  24554.10     YES         0  YES      YES
# ID12563   23  FEMALE  INNER_CITY  18050.00     YES         0  YES       NO
# ID12564   29  FEMALE       RURAL  15237.60     YES         2  YES       NO
# ID12565   28    MALE        TOWN  20555.00      NO         0  YES      YES
# ID12566   57  FEMALE        TOWN  28421.70     YES         2  YES      YES
# ID12567   38    MALE  INNER_CITY  21876.50     YES         0   NO       NO
# ID12568   34  FEMALE    SUBURBAN  12810.20      NO         3   NO      YES
# ID12569   43    MALE    SUBURBAN  15109.40     YES         0   NO       NO
# ID12570   63    MALE        TOWN  37414.70      NO         3  YES      YES
# ID12571   62  FEMALE  INNER_CITY  41521.60     YES         0   NO      YES
# ID12572   51  FEMALE  INNER_CITY  25372.80     YES         0  YES      YES
# ID12573   61    MALE  INNER_CITY  21139.80     YES         2  YES      YES
# ID12574   41  FEMALE        TOWN  27757.60      NO         0   NO      YES
# ID12575   31  FEMALE        TOWN  22678.10      NO         1  YES      YES
# ID12576   33  FEMALE        TOWN  12178.50     YES         2   NO      YES
# ID12577   43    MALE       RURAL  26106.70      NO         1   NO       NO
# ID12578   40    MALE  INNER_CITY  27417.60     YES         0   NO      YES
# ID12579   47    MALE        TOWN  23337.20     YES         2   NO      YES
#
#         current_act mortgage  pep
# id
# ID12101          NO       NO  YES
# ID12102         YES      YES   NO
# ID12103         YES       NO   NO
# ID12104         YES       NO   NO
# ID12105          NO       NO   NO
# ID12106         YES       NO  YES
# ID12107         YES       NO  YES
# ID12108         YES       NO   NO
# ID12109          NO       NO   NO
# ID12110         YES       NO   NO
# ID12111         YES       NO   NO
# ID12112         YES      YES   NO
# ID12113         YES      YES  YES
# ID12114         YES      YES  YES
# ID12115         YES      YES   NO
# ID12116         YES      YES   NO
# ID12117          NO      YES   NO
# ID12118          NO      YES   NO
# ID12119          NO       NO  YES
# ID12120         YES       NO   NO
# ID12121          NO       NO  YES
# ID12122         YES       NO   NO
# ID12123         YES       NO   NO
# ID12124         YES      YES   NO
# ID12125         YES       NO   NO
# ID12126         YES      YES   NO
# ID12127         YES      YES   NO
# ID12128         YES       NO  YES
# ID12129         YES      YES   NO
# ID12130         YES       NO  YES
# ...             ...      ...  ...
# ID12550         YES       NO  YES
# ID12551          NO       NO   NO
# ID12552          NO      YES   NO
# ID12553         YES       NO  YES
# ID12554         YES      YES   NO
# ID12555         YES      YES   NO
# ID12556         YES       NO   NO
# ID12557         YES      YES   NO
# ID12558         YES       NO   NO
# ID12559         YES       NO   NO
# ID12560         YES       NO  YES
# ID12561         YES      YES  YES
# ID12562          NO      YES   NO
# ID12563         YES      YES  YES
# ID12564         YES       NO   NO
# ID12565         YES       NO  YES
# ID12566         YES      YES   NO
# ID12567         YES       NO   NO
# ID12568         YES       NO  YES
# ID12569         YES       NO  YES
# ID12570         YES       NO   NO
# ID12571         YES      YES   NO
# ID12572         YES       NO   NO
# ID12573          NO       NO   NO
# ID12574         YES       NO  YES
# ID12575         YES      YES  YES
# ID12576         YES      YES   NO
# ID12577         YES       NO  YES
# ID12578         YES      YES   NO
# ID12579         YES      YES   NO
#
# [479 rows x 11 columns]

# %%
# import library for preprocessing
le = preprocessing.LabelEncoder()

# %%
# Tranform data using "fit_transform(attribute)" function  
dataset.car = le.fit_transform(dataset.car)
dataset.sex = le.fit_transform(dataset.sex)
dataset.save_act = le.fit_transform(dataset.save_act)
dataset.married = le.fit_transform(dataset.married)
dataset.current_act = le.fit_transform(dataset.current_act)
dataset.mortgage = le.fit_transform(dataset.mortgage)
dataset.pep = le.fit_transform(dataset.pep)

# %%
# Convert "Region" into presence absence attribute
dataset = pd.concat([dataset,pd.get_dummies(dataset['region'], prefix='REG')],axis=1)
dataset.drop(['region'],axis=1, inplace=True)
# Out:
#          age  sex   income  married  children  car  save_act  current_act  \
# id
# ID12101   48    0  17546.0        0         1    0         0            0
# ID12102   40    1  30085.1        1         3    1         0            1
# ID12103   51    0  16575.4        1         0    1         1            1
# ID12104   23    0  20375.4        1         3    0         0            1
# ID12105   57    0  50576.3        1         0    0         1            0
#
#          mortgage  pep  REG_INNER_CITY  REG_RURAL  REG_SUBURBAN  REG_TOWN
# id
# ID12101         0    1               1          0             0         0
# ID12102         1    0               0          0             0         1
# ID12103         0    0               1          0             0         0
# ID12104         0    0               0          0             0         1
# ID12105         0    0               0          1             0         0

# %%
# display dataframe first 5 columns
dataset.head(5)
# Out:
#          age  sex   income  married  children  car  save_act  current_act  \
# id
# ID12101   48    0  17546.0        0         1    0         0            0
# ID12102   40    1  30085.1        1         3    1         0            1
# ID12103   51    0  16575.4        1         0    1         1            1
# ID12104   23    0  20375.4        1         3    0         0            1
# ID12105   57    0  50576.3        1         0    0         1            0
#
#          mortgage  pep  REG_INNER_CITY  REG_RURAL  REG_SUBURBAN  REG_TOWN
# id
# ID12101         0    1               1          0             0         0
# ID12102         1    0               0          0             0         1
# ID12103         0    0               1          0             0         0
# ID12104         0    0               0          0             0         1
# ID12105         0    0               0          1             0         0

# %% [markdown]
# ### Train and Test Split

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'income', 'married', 'children', 'car', 'save_act',
#        'current_act', 'mortgage', 'pep', 'REG_INNER_CITY', 'REG_RURAL',
#        'REG_SUBURBAN', 'REG_TOWN'],
#       dtype='object')

# %%
# Select the independent variables and the target attribute
X = dataset[['age', 'sex', 'income', 'married', 'children', 'car', 'save_act',
       'current_act', 'mortgage', 'REG_INNER_CITY', 'REG_RURAL',
       'REG_SUBURBAN', 'REG_TOWN']]
Y = dataset['pep']

# %%
X.head()
# Out:
#          age  sex   income  married  children  car  save_act  current_act  \
# id
# ID12101   48    0  17546.0        0         1    0         0            0
# ID12102   40    1  30085.1        1         3    1         0            1
# ID12103   51    0  16575.4        1         0    1         1            1
# ID12104   23    0  20375.4        1         3    0         0            1
# ID12105   57    0  50576.3        1         0    0         1            0
#
#          mortgage  REG_INNER_CITY  REG_RURAL  REG_SUBURBAN  REG_TOWN
# id
# ID12101         0               1          0             0         0
# ID12102         1               0          0             0         1
# ID12103         0               1          0             0         0
# ID12104         0               0          0             0         1
# ID12105         0               0          1             0         0

# %% [markdown]
# #### Obtain X_train, X_test, Y_train, Y_test by splitting the dataset into 70-30 ratio with a random state value 30.
#
# Note: random_state is used to control the shuffling in the split of the dataset.
#
# This method is called the Hold Out Method.

# %%
# Divide the dataset into training and testing partition
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state = 30)

# %% [markdown]
# ### Import the k-NN Classifier library

# %%
# import KNeighborsClassifier library
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Train 3-NN by using euclidean distance as distance measure

# %%
# Apply the classifier
knn=KNeighborsClassifier(n_neighbors=3, metric='euclidean')
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %% [markdown]
# ### Prediction and Evaluation

# %%
# import required libraries
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score

# %%
# predictions for testing partition
predictions = knn.predict(X_test)

# %%
# Calculate and print confusion matrix and other performance measures (Refer previous labsheet)
print(classification_report(Y_test,predictions))
print("Confusion Matrix")
print(confusion_matrix(Y_test,predictions))
print("\n Accuracy")
print(accuracy_score(Y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57        80
#            1       0.44      0.39      0.41        64
#
#     accuracy                           0.51       144
#    macro avg       0.50      0.50      0.49       144
# weighted avg       0.50      0.51      0.50       144
#
# Confusion Matrix
# [[48 32]
#  [39 25]]
#
#  Accuracy
# 0.5069444444444444

# %% [markdown]
# ###  k(5) - fold method for training and testing split and check the difference in performance of 3-NN

# %%
# Import required library for K-fold and test the performance of model using Eucledean distance
from sklearn.model_selection import cross_val_score
knn_cv = KNeighborsClassifier(n_neighbors=3, metric = 'euclidean')
scores = cross_val_score(knn_cv, X, Y, cv=5, scoring='accuracy')
print('scores: ', scores)
print('mean score: ', scores.mean())
# Out:
# scores:  [0.52083333 0.55208333 0.5625     0.58333333 0.55789474]
# mean score:  0.5553289473684211

# %%
#accuracy is better than holdout method

# %% [markdown]
# #### Q1: Normalize (min-max normalization) age,income and children columns of the dataset and apply 3-NN using both euclidean and manhattan distance

# %%
#min-max normalization
for col in ['age','income','children']:
    dataset[col] = (dataset[col]-dataset[col].min())/(dataset[col].max()-dataset[col].min())
dataset.head()
# Out:
#               age  sex    income  married  children  car  save_act  \
# id
# ID12101  0.612245    0  0.215634        0  0.333333    0         0
# ID12102  0.448980    1  0.431395        1  1.000000    1         0
# ID12103  0.673469    0  0.198933        1  0.000000    1         1
# ID12104  0.102041    0  0.264320        1  1.000000    0         0
# ID12105  0.795918    0  0.783987        1  0.000000    0         1
#
#          current_act  mortgage  pep  REG_INNER_CITY  REG_RURAL  REG_SUBURBAN  \
# id
# ID12101            0         0    1               1          0             0
# ID12102            1         1    0               0          0             0
# ID12103            1         0    0               1          0             0
# ID12104            1         0    0               0          0             0
# ID12105            0         0    0               0          1             0
#
#          REG_TOWN
# id
# ID12101         0
# ID12102         1
# ID12103         0
# ID12104         1
# ID12105         0

# %%
# Select the independent variables and the target attribute
X = dataset[['age', 'sex', 'income', 'married', 'children', 'car', 'save_act',
       'current_act', 'mortgage', 'REG_INNER_CITY', 'REG_RURAL',
       'REG_SUBURBAN', 'REG_TOWN']]
Y = dataset['pep']

# %%
# KNN using euclidean distance
knn_cv_euc = KNeighborsClassifier(n_neighbors=3, metric = 'euclidean')
scores = cross_val_score(knn_cv_euc, X, Y, cv=5, scoring='accuracy')
print('scores: ', scores)
print('mean score: ', scores.mean())
# Out:
# scores:  [0.60416667 0.625      0.59375    0.59375    0.56842105]
# mean score:  0.5970175438596491

# %%
# KNN using manhattan distance
knn_cv_man = KNeighborsClassifier(n_neighbors=3, metric = 'manhattan')
scores = cross_val_score(knn_cv_man, X, Y, cv=5, scoring='accuracy')
print('scores: ', scores)
print('mean score: ', scores.mean())
# Out:
# scores:  [0.66666667 0.70833333 0.66666667 0.65625    0.61052632]
# mean score:  0.661688596491228

# %% [markdown]
# #### Q2: Write your observation regarding change in the perfromance of KNN

# %% [raw]
# #accuracy has improved after normalization

# %% [markdown]
# #### Q3: Find the accuracy of 1-NN model

# %%
# Use euclidean distance
knn_cv = KNeighborsClassifier(n_neighbors=1, metric = 'euclidean')
scores = cross_val_score(knn_cv, X, Y, cv=5, scoring='accuracy')
print('scores: ', scores)
print('mean score: ', scores.mean())
# Out:
# scores:  [0.625      0.70833333 0.59375    0.63541667 0.63157895]
# mean score:  0.6388157894736842

# %% [markdown]
# #### Q4: Implement the weighted k-NN model. Use k-fold method for train-test split

# %%
# Refer labsheet 4
knn = KNeighborsClassifier(n_neighbors=3, metric = 'euclidean' , weights= 'distance') 
scores = cross_val_score(knn, X, Y, cv=5, scoring='accuracy')
print("Accuracy score", scores.mean())
# Out:
# Accuracy score 0.6262061403508772

# %% [markdown]
# #### Q5: What is the best k value in this model

# %%
# Refer labsheet 4
lis = []
for k in range(1,21):
    knn_cv = KNeighborsClassifier(n_neighbors=k, metric = 'euclidean', weights= 'distance')
    scores = cross_val_score(knn_cv, X, Y, cv=5, scoring='accuracy')
    print("Accuracy score for k : " +str(k) + " ", scores.mean())
    lis.append(scores.mean());
# Out:
# Accuracy score for k : 1  0.6388157894736842
# Accuracy score for k : 2  0.6388157894736842
# Accuracy score for k : 3  0.6262061403508772
# Accuracy score for k : 4  0.6429385964912282
# Accuracy score for k : 5  0.626140350877193
# Accuracy score for k : 6  0.6387280701754386
# Accuracy score for k : 7  0.6511842105263158
# Accuracy score for k : 8  0.6491666666666667
# Accuracy score for k : 9  0.6429605263157895
# Accuracy score for k : 10  0.6325000000000001
# Accuracy score for k : 11  0.6428947368421053
# Accuracy score for k : 12  0.6387061403508772
# Accuracy score for k : 13  0.6303508771929824
# Accuracy score for k : 14  0.6262061403508772
# Accuracy score for k : 15  0.6346052631578948
# Accuracy score for k : 16  0.6262719298245614
# Accuracy score for k : 17  0.6325657894736842
# Accuracy score for k : 18  0.6346710526315789
# Accuracy score for k : 19  0.6430043859649123
# Accuracy score for k : 20  0.6576535087719299

# %%
# Refer labsheet 4

# %%
# Refer labsheet 4

# %% [markdown]
# #### Q6: Consider "current_act" as an irrelevant attribute. Remove it and find the accuracy of KNN classifier

# %%
# Select the independent variables and the target attribute after dropping specified column
X.drop('current_act', axis = 1, inplace =True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
# Use euclidean distance as distance metric and k(5) -fold method of test train
knn_cv_euc = KNeighborsClassifier(n_neighbors=3, metric = 'euclidean')
scores = cross_val_score(knn_cv_euc, X, Y, cv=5, scoring='accuracy')
print('scores: ', scores)
print('mean score: ', scores.mean())
# Out:
# scores:  [0.57291667 0.625      0.69791667 0.6875     0.58947368]
# mean score:  0.6345614035087719

# %% [markdown]
# #### Q7: Write your observation

# %%
#Accuracy has improved after removing "current-act" attribute
